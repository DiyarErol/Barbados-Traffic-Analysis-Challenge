# %% [markdown]
# # Barbados Trafik Sıkışıklığı Analizi - Kapsamlı Çözüm
#
# Norman Niles kavşağındaki trafik sıkışıklığını video verilerinden tahmin eden detaylı Jupyter Notebook.
#
# ## 🎯 Proje Hedefi
#
# - **Veri**: 4 kameradan ~1 dakikalık video segmentleri
# - **Çıktı**: Tıkanıklık seviyeleri ["serbest akış", "hafif gecikme", "orta gecikme", "ağır gecikme"]
# - **Kısıtlamalar**:
#   - Geri yayılım yok (inference sırasında)
#   - Gerçek zamanlı: 15dk input → 2dk embargo → 5dk tahmin
#   - Manuel etiketleme yasak
#
# ## 📋 İçerik
#
# 1. Ortam Hazırlığı ve Kütüphaneler
# 2. Veri Keşfi ve Analiz
# 3. Video İşleme Pipeline
# 4. Özellik Çıkarma
# 5. Model Eğitimi
# 6. Gerçek Zamanlı Tahmin
# 7. Performans Değerlendirme
